# %% [markdown]
# # 나의 프로젝트 노트입니다. 중요한 코드나 문서를 함께 작성할 거예용~
# - 작성일: 2026.9.8
# - 작성자: 윤종하
#
# 그 외의 표나 그림을 저장할 수 있어용~~!

# %%
print("안녕하세요")
x = 3
print(x)
# Out:
# 안녕하세요
# 3

# %% [markdown]
# 이 알고리즘은 아주 간단합니다.
# 백트레킹 알고리즘을 사용하였으며 ,
